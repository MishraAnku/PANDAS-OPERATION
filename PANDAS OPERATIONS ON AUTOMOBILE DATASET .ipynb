# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#
# In \[2\]:
#
#     auto=pd.read_csv("Automobile_data.csv")
#
# In \[3\]:
#
#     auto.head()
#
# Out\[3\]:
#
# |     | symboling | normalized-losses | make        | fuel-type | aspiration | num-of-doors | body-style  | drive-wheels | engine-location | wheel-base | ... | engine-size | fuel-system | bore | stroke | compression-ratio | horsepower | peak-rpm | city-mpg | highway-mpg | price |
# |-----|-----------|-------------------|-------------|-----------|------------|--------------|-------------|--------------|-----------------|------------|-----|-------------|-------------|------|--------|-------------------|------------|----------|----------|-------------|-------|
# | 0   | 3         | ?                 | alfa-romero | gas       | std        | two          | convertible | rwd          | front           | 88.6       | ... | 130         | mpfi        | 3.47 | 2.68   | 9.0               | 111        | 5000     | 21       | 27          | 13495 |
# | 1   | 3         | ?                 | alfa-romero | gas       | std        | two          | convertible | rwd          | front           | 88.6       | ... | 130         | mpfi        | 3.47 | 2.68   | 9.0               | 111        | 5000     | 21       | 27          | 16500 |
# | 2   | 1         | ?                 | alfa-romero | gas       | std        | two          | hatchback   | rwd          | front           | 94.5       | ... | 152         | mpfi        | 2.68 | 3.47   | 9.0               | 154        | 5000     | 19       | 26          | 16500 |
# | 3   | 2         | 164               | audi        | gas       | std        | four         | sedan       | fwd          | front           | 99.8       | ... | 109         | mpfi        | 3.19 | 3.4    | 10.0              | 102        | 5500     | 24       | 30          | 13950 |
# | 4   | 2         | 164               | audi        | gas       | std        | four         | sedan       | 4wd          | front           | 99.4       | ... | 136         | mpfi        | 3.19 | 3.4    | 8.0               | 115        | 5500     | 18       | 22          | 17450 |
#
# 5 rows × 26 columns
#
# In \[4\]:
#
#     auto.tail()
#
# Out\[4\]:
#
# |     | symboling | normalized-losses | make  | fuel-type | aspiration | num-of-doors | body-style | drive-wheels | engine-location | wheel-base | ... | engine-size | fuel-system | bore | stroke | compression-ratio | horsepower | peak-rpm | city-mpg | highway-mpg | price |
# |-----|-----------|-------------------|-------|-----------|------------|--------------|------------|--------------|-----------------|------------|-----|-------------|-------------|------|--------|-------------------|------------|----------|----------|-------------|-------|
# | 200 | -1        | 95                | volvo | gas       | std        | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 9.5               | 114        | 5400     | 23       | 28          | 16845 |
# | 201 | -1        | 95                | volvo | gas       | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 8.7               | 160        | 5300     | 19       | 25          | 19045 |
# | 202 | -1        | 95                | volvo | gas       | std        | four         | sedan      | rwd          | front           | 109.1      | ... | 173         | mpfi        | 3.58 | 2.87   | 8.8               | 134        | 5500     | 18       | 23          | 21485 |
# | 203 | -1        | 95                | volvo | diesel    | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 145         | idi         | 3.01 | 3.4    | 23.0              | 106        | 4800     | 26       | 27          | 22470 |
# | 204 | -1        | 95                | volvo | gas       | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 9.5               | 114        | 5400     | 19       | 25          | 22625 |
#
# 5 rows × 26 columns
#
# In \[5\]:
#
#     auto.info
#
# Out\[5\]:
#
#     <bound method DataFrame.info of      symboling normalized-losses         make fuel-type aspiration  \
#     0            3                 ?  alfa-romero       gas        std
#     1            3                 ?  alfa-romero       gas        std
#     2            1                 ?  alfa-romero       gas        std
#     3            2               164         audi       gas        std
#     4            2               164         audi       gas        std
#     ..         ...               ...          ...       ...        ...
#     200         -1                95        volvo       gas        std
#     201         -1                95        volvo       gas      turbo
#     202         -1                95        volvo       gas        std
#     203         -1                95        volvo    diesel      turbo
#     204         -1                95        volvo       gas      turbo
#
#         num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
#     0            two  convertible          rwd           front        88.6  ...
#     1            two  convertible          rwd           front        88.6  ...
#     2            two    hatchback          rwd           front        94.5  ...
#     3           four        sedan          fwd           front        99.8  ...
#     4           four        sedan          4wd           front        99.4  ...
#     ..           ...          ...          ...             ...         ...  ...
#     200         four        sedan          rwd           front       109.1  ...
#     201         four        sedan          rwd           front       109.1  ...
#     202         four        sedan          rwd           front       109.1  ...
#     203         four        sedan          rwd           front       109.1  ...
#     204         four        sedan          rwd           front       109.1  ...
#
#          engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     0            130         mpfi  3.47    2.68               9.0        111
#     1            130         mpfi  3.47    2.68               9.0        111
#     2            152         mpfi  2.68    3.47               9.0        154
#     3            109         mpfi  3.19     3.4              10.0        102
#     4            136         mpfi  3.19     3.4               8.0        115
#     ..           ...          ...   ...     ...               ...        ...
#     200          141         mpfi  3.78    3.15               9.5        114
#     201          141         mpfi  3.78    3.15               8.7        160
#     202          173         mpfi  3.58    2.87               8.8        134
#     203          145          idi  3.01     3.4              23.0        106
#     204          141         mpfi  3.78    3.15               9.5        114
#
#          peak-rpm city-mpg highway-mpg  price
#     0        5000       21          27  13495
#     1        5000       21          27  16500
#     2        5000       19          26  16500
#     3        5500       24          30  13950
#     4        5500       18          22  17450
#     ..        ...      ...         ...    ...
#     200      5400       23          28  16845
#     201      5300       19          25  19045
#     202      5500       18          23  21485
#     203      4800       26          27  22470
#     204      5400       19          25  22625
#
#     [205 rows x 26 columns]>
#
# In \[6\]:
#
#     auto.describe
#
# Out\[6\]:
#
#     <bound method NDFrame.describe of      symboling normalized-losses         make fuel-type aspiration  \
#     0            3                 ?  alfa-romero       gas        std
#     1            3                 ?  alfa-romero       gas        std
#     2            1                 ?  alfa-romero       gas        std
#     3            2               164         audi       gas        std
#     4            2               164         audi       gas        std
#     ..         ...               ...          ...       ...        ...
#     200         -1                95        volvo       gas        std
#     201         -1                95        volvo       gas      turbo
#     202         -1                95        volvo       gas        std
#     203         -1                95        volvo    diesel      turbo
#     204         -1                95        volvo       gas      turbo
#
#         num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
#     0            two  convertible          rwd           front        88.6  ...
#     1            two  convertible          rwd           front        88.6  ...
#     2            two    hatchback          rwd           front        94.5  ...
#     3           four        sedan          fwd           front        99.8  ...
#     4           four        sedan          4wd           front        99.4  ...
#     ..           ...          ...          ...             ...         ...  ...
#     200         four        sedan          rwd           front       109.1  ...
#     201         four        sedan          rwd           front       109.1  ...
#     202         four        sedan          rwd           front       109.1  ...
#     203         four        sedan          rwd           front       109.1  ...
#     204         four        sedan          rwd           front       109.1  ...
#
#          engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     0            130         mpfi  3.47    2.68               9.0        111
#     1            130         mpfi  3.47    2.68               9.0        111
#     2            152         mpfi  2.68    3.47               9.0        154
#     3            109         mpfi  3.19     3.4              10.0        102
#     4            136         mpfi  3.19     3.4               8.0        115
#     ..           ...          ...   ...     ...               ...        ...
#     200          141         mpfi  3.78    3.15               9.5        114
#     201          141         mpfi  3.78    3.15               8.7        160
#     202          173         mpfi  3.58    2.87               8.8        134
#     203          145          idi  3.01     3.4              23.0        106
#     204          141         mpfi  3.78    3.15               9.5        114
#
#          peak-rpm city-mpg highway-mpg  price
#     0        5000       21          27  13495
#     1        5000       21          27  16500
#     2        5000       19          26  16500
#     3        5500       24          30  13950
#     4        5500       18          22  17450
#     ..        ...      ...         ...    ...
#     200      5400       23          28  16845
#     201      5300       19          25  19045
#     202      5500       18          23  21485
#     203      4800       26          27  22470
#     204      5400       19          25  22625
#
#     [205 rows x 26 columns]>
#
# In \[8\]:
#
#     auto.columns
#
# Out\[8\]:
#
#     Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#            'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#            'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#            'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#            'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#            'highway-mpg', 'price'],
#           dtype='object')
#
# In \[9\]:
#
#     auto.shape
#
# Out\[9\]:
#
#     (205, 26)
#
# In \[10\]:
#
#     auto.size
#
# Out\[10\]:
#
#     5330
#
# In \[17\]:
#
#     # what is the average price of all cars in a dataset ?
#
#     import pandas as pd
#
#     # Load the dataset
#     auto = pd.read_csv('automobile_data.csv')
#
#     # Replace non-numeric values with NaN
#     auto['stroke'] = pd.to_numeric(auto['stroke'], errors='coerce')
#
#     # Calculate the average stroke
#     average_stroke = auto['stroke'].mean()
#
#     print("Average stroke of all cars:", average_stroke)
#
#     Average stroke of all cars: 3.255422885572139
#
# In \[23\]:
#
#     # what is the ceapest make & costliest make of the car in the lot ?
#
#     import pandas as pd
#
#     # Load the dataset
#     auto = pd.read_csv('Automobile_data.csv')  # Replace 'automobile_dataset.csv' with the name of your dataset file
#
#     # Convert the 'price' column to numeric
#     auto['price'] = pd.to_numeric(auto['price'], errors='coerce')
#
#     # Find the cheapest make
#     cheapest_make = auto.loc[auto['price'].idxmin()]['make']
#
#     # Find the costliest make
#     costliest_make = auto.loc[auto['price'].idxmax()]['make']
#
#     print("Cheapest make:", cheapest_make)
#     print("Costliest make:", costliest_make)
#
#     Cheapest make: subaru
#     Costliest make: mercedes-benz
#
# In \[25\]:
#
#     # # how many cars have horsepower greater than 100?
#
#     import pandas as pd
#
#     # Load the CSV data into a DataFrame
#     df = pd.read_csv('automobile_data.csv')
#
#     # Convert 'horsepower' column to numeric values (assuming it contains numeric data)
#     df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
#
#     # Filter the DataFrame to include only cars with horsepower greater than 100
#     cars_greater_than_100_hp = df[df['horsepower'] > 100]
#
#     # Count the number of rows in the filtered DataFrame
#     num_cars_greater_than_100_hp = len(cars_greater_than_100_hp)
#
#     print("Number of cars with horsepower greater than 100:", num_cars_greater_than_100_hp)
#
#     Number of cars with horsepower greater than 100: 92
#
# In \[27\]:
#
#     # # how many hatchback cars are in the dataset ?
#
#     import pandas as pd
#
#     # Read the CSV file into a DataFrame
#     df = pd.read_csv('automobile_data.csv')
#
#     # Print out the column names
#     print(df.columns)
#
#     # Filter the DataFrame to include only hatchback cars if 'body_style' exists
#     if 'body_style' in df.columns:
#         hatchback_cars = df[df['body_style'] == 'hatchback']
#         num_hatchback_cars = hatchback_cars.shape[0]
#         print("Number of hatchback cars in the dataset:", num_hatchback_cars)
#     else:
#         print("The 'body_style' column does not exist in the dataset.")
#
#     Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#            'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#            'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#            'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#            'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#            'highway-mpg', 'price'],
#           dtype='object')
#     The 'body_style' column does not exist in the dataset.
#
# In \[28\]:
#
#     # what are the 3 most commonly found cars in the dataset ?
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('automobile_data.csv')
#
#     # Count the occurrences of each car make
#     car_counts = df['make'].value_counts()
#
#     # Get the top 3 most common car makes
#     top_3_cars = car_counts.head(3)
#
#     print("The top 3 most commonly found cars are:")
#     print(top_3_cars)
#
#     The top 3 most commonly found cars are:
#     make
#     toyota    32
#     nissan    18
#     mazda     17
#     Name: count, dtype: int64
#
# In \[30\]:
#
#     # # someone purchased a car for 7099 , what is the make of car ?
#
#     import pandas as pd
#
#     # Load the dataset
#     df = pd.read_csv('automobile_data.csv')
#
#     # Find the row where the price matches 7099
#     car_info = df[df['price'] == 7099]
#
#     # Check if any rows were found
#     if not car_info.empty:
#         # Extract the make of the car
#         car_make = car_info['make'].values[0]
#         print("The make of the car purchased for $7099 is:", car_make)
#     else:
#         print("No car found with a price of $7099.")
#
#     No car found with a price of $7099.
#
# In \[32\]:
#
#     # # which cars are priced greater than 40000?
#     import pandas as pd
#
#     # Load the CSV file into a DataFrame
#     df = pd.read_csv("automobile_data.csv")
#
#     # Convert the 'price' column to numeric
#     df['price'] = pd.to_numeric(df['price'], errors='coerce')
#
#     # Filter the DataFrame for cars priced greater than $40,000
#     expensive_cars = df[df['price'] > 40000]
#
#     # Display the results
#     print(expensive_cars)
#
#         symboling normalized-losses           make fuel-type aspiration  \
#     16          0                 ?            bmw       gas        std
#     73          0                 ?  mercedes-benz       gas        std
#     74          1                 ?  mercedes-benz       gas        std
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
#     16          two      sedan          rwd           front       103.5  ...
#     73         four      sedan          rwd           front       120.9  ...
#     74          two    hardtop          rwd           front       112.0  ...
#
#         engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     16          209         mpfi  3.62    3.39               8.0        182
#     73          308         mpfi   3.8    3.35               8.0        184
#     74          304         mpfi   3.8    3.35               8.0        184
#
#         peak-rpm city-mpg highway-mpg    price
#     16      5400       16          22  41315.0
#     73      4500       14          16  40960.0
#     74      4500       14          16  45400.0
#
#     [3 rows x 26 columns]
#
# In \[35\]:
#
#     # which are the cars that both are sedan & priced less than 5000 ?
#
#     import pandas as pd
#
#     # Load the dataset
#     data = pd.read_csv("automobile_data.csv")
#
#     # Convert 'price' column to numeric
#     data['price'] = pd.to_numeric(data['price'], errors='coerce')
#
#     # Filter for sedans priced less than $5000
#     filtered_data = data[(data['body-style'] == 'sedan') & (data['price'] < 5000)]
#
#     # Display the filtered data
#     print(filtered_data[['make', 'price']])
#
#     Empty DataFrame
#     Columns: [make, price]
#     Index: []
#
# In \[37\]:
#
#     # #  which are the cars that both are sedan & priced less than 7000 ?
#
#     import pandas as pd
#
#     # Load the CSV file into a pandas DataFrame
#     df = pd.read_csv("automobile_data.csv")
#
#     # Convert 'price' column to numeric
#     df['price'] = pd.to_numeric(df['price'], errors='coerce')
#
#     # Filter the DataFrame for sedans priced less than $7000
#     filtered_cars = df[(df['body-style'] == 'sedan') & (df['price'] < 7000)]
#
#     # Display the filtered cars
#     print(filtered_cars)
#
#          symboling normalized-losses        make fuel-type aspiration  \
#     20           0                81   chevrolet       gas        std
#     25           1               148       dodge       gas        std
#     43           0                 ?       isuzu       gas        std
#     53           1               113       mazda       gas        std
#     85           1               125  mitsubishi       gas        std
#     89           1               128      nissan       gas        std
#     91           1               128      nissan       gas        std
#     92           1               122      nissan       gas        std
#     121          1               154    plymouth       gas        std
#     156          0                91      toyota       gas        std
#
#         num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
#     20          four      sedan          fwd           front        94.5  ...
#     25          four      sedan          fwd           front        93.7  ...
#     43          four      sedan          rwd           front        94.3  ...
#     53          four      sedan          fwd           front        93.1  ...
#     85          four      sedan          fwd           front        96.3  ...
#     89           two      sedan          fwd           front        94.5  ...
#     91           two      sedan          fwd           front        94.5  ...
#     92          four      sedan          fwd           front        94.5  ...
#     121         four      sedan          fwd           front        93.7  ...
#     156         four      sedan          fwd           front        95.7  ...
#
#          engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     20            90         2bbl  3.03    3.11               9.6         70
#     25            90         2bbl  2.97    3.23               9.4         68
#     43           111         2bbl  3.31    3.23               8.5         78
#     53            91         2bbl  3.03    3.15               9.0         68
#     85           122         2bbl  3.35    3.46               8.5         88
#     89            97         2bbl  3.15    3.29               9.4         69
#     91            97         2bbl  3.15    3.29               9.4         69
#     92            97         2bbl  3.15    3.29               9.4         69
#     121           90         2bbl  2.97    3.23               9.4         68
#     156           98         2bbl  3.19    3.03               9.0         70
#
#          peak-rpm city-mpg highway-mpg   price
#     20       5400       38          43  6575.0
#     25       5500       31          38  6692.0
#     43       4800       24          29  6785.0
#     53       5000       31          38  6695.0
#     85       5000       25          32  6989.0
#     89       5200       31          37  5499.0
#     91       5200       31          37  6649.0
#     92       5200       31          37  6849.0
#     121      5500       31          38  6692.0
#     156      4800       30          37  6938.0
#
#     [10 rows x 26 columns]
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
